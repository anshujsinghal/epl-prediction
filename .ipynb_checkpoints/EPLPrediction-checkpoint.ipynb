# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime as dt
import itertools

# %matplotlib inline

# %%
df = pd.read_csv('epl_final.csv')

# %%
df.head()
# Out:
#     Season   MatchDate  HomeTeam       AwayTeam  FullTimeHomeGoals  \
# 0  2000/01  2000-08-19  Charlton       Man City                  4
# 1  2000/01  2000-08-19   Chelsea       West Ham                  4
# 2  2000/01  2000-08-19  Coventry  Middlesbrough                  1
# 3  2000/01  2000-08-19     Derby    Southampton                  2
# 4  2000/01  2000-08-19     Leeds        Everton                  2
#
#    FullTimeAwayGoals FullTimeResult  HalfTimeHomeGoals  HalfTimeAwayGoals  \
# 0                  0              H                  2                  0
# 1                  2              H                  1                  0
# 2                  3              A                  1                  1
# 3                  2              D                  1                  2
# 4                  0              H                  2                  0
#
#   HalfTimeResult  ...  HomeShotsOnTarget  AwayShotsOnTarget  HomeCorners  \
# 0              H  ...                 14                  4            6
# 1              H  ...                 10                  5            7
# 2              D  ...                  3                  9            8
# 3              A  ...                  4                  6            5
# 4              H  ...                  8                  6            6
#
#    AwayCorners  HomeFouls  AwayFouls  HomeYellowCards  AwayYellowCards  \
# 0            6         13         12                1                2
# 1            7         19         14                1                2
# 2            4         15         21                5                3
# 3            8         11         13                1                1
# 4            4         21         20                1                3
#
#    HomeRedCards  AwayRedCards
# 0             0             0
# 1             0             0
# 2             1             0
# 3             0             0
# 4             0             0
#
# [5 rows x 22 columns]

# %%
df["MatchDate"] = pd.to_datetime(df["MatchDate"])

df["Year"] = df["MatchDate"].dt.year
df["Month"] = df["MatchDate"].dt.month
df["Day"] = df["MatchDate"].dt.day

# %%
df.head()
# Out:
#     Season  MatchDate  HomeTeam       AwayTeam  FullTimeHomeGoals  \
# 0  2000/01 2000-08-19  Charlton       Man City                  4
# 1  2000/01 2000-08-19   Chelsea       West Ham                  4
# 2  2000/01 2000-08-19  Coventry  Middlesbrough                  1
# 3  2000/01 2000-08-19     Derby    Southampton                  2
# 4  2000/01 2000-08-19     Leeds        Everton                  2
#
#    FullTimeAwayGoals FullTimeResult  HalfTimeHomeGoals  HalfTimeAwayGoals  \
# 0                  0              H                  2                  0
# 1                  2              H                  1                  0
# 2                  3              A                  1                  1
# 3                  2              D                  1                  2
# 4                  0              H                  2                  0
#
#   HalfTimeResult  ...  AwayCorners  HomeFouls  AwayFouls  HomeYellowCards  \
# 0              H  ...            6         13         12                1
# 1              H  ...            7         19         14                1
# 2              D  ...            4         15         21                5
# 3              A  ...            8         11         13                1
# 4              H  ...            4         21         20                1
#
#    AwayYellowCards  HomeRedCards  AwayRedCards  Year  Month  Day
# 0                2             0             0  2000      8   19
# 1                2             0             0  2000      8   19
# 2                3             1             0  2000      8   19
# 3                1             0             0  2000      8   19
# 4                3             0             0  2000      8   19
#
# [5 rows x 25 columns]

# %%
def rolling_team_feature(df, team_col, stat_col, window=20):
    return df.groupby(team_col)[stat_col].transform(
        lambda x: x.shift().rolling(window=window, min_periods=1).mean()
    )
df["HomeAvgGoalsScored"] = rolling_team_feature(
    df, "HomeTeam", "FullTimeHomeGoals"
)
df["AwayAvgGoalsScored"] = rolling_team_feature(
    df, "AwayTeam", "FullTimeAwayGoals"
)

df["HomeAvgGoalsConceded"] = rolling_team_feature(
    df, "HomeTeam", "FullTimeAwayGoals"
)
df["AwayAvgGoalsConceded"] = rolling_team_feature(
    df, "AwayTeam", "FullTimeHomeGoals"
)

# %%
df.tail()
# Out:
#        Season  MatchDate        HomeTeam       AwayTeam  FullTimeHomeGoals  \
# 9375  2024/25 2025-05-04       Brentford     Man United                  4
# 9376  2024/25 2025-05-04        Brighton      Newcastle                  1
# 9377  2024/25 2025-05-04        West Ham      Tottenham                  1
# 9378  2024/25 2025-05-04         Chelsea      Liverpool                  3
# 9379  2024/25 2025-05-05  Crystal Palace  Nott'm Forest                  1
#
#       FullTimeAwayGoals FullTimeResult  HalfTimeHomeGoals  HalfTimeAwayGoals  \
# 9375                  3              H                  2                  1
# 9376                  1              D                  1                  0
# 9377                  1              D                  1                  1
# 9378                  1              H                  1                  0
# 9379                  1              D                  0                  0
#
#      HalfTimeResult  ...  AwayYellowCards  HomeRedCards  AwayRedCards  Year  \
# 9375              H  ...                2             0             0  2025
# 9376              H  ...                1             0             0  2025
# 9377              D  ...                2             0             0  2025
# 9378              H  ...                2             0             0  2025
# 9379              D  ...                8             0             0  2025
#
#       Month  Day  HomeAvgGoalsScored  AwayAvgGoalsScored  \
# 9375      5    4                 1.9                1.10
# 9376      5    4                 1.4                1.85
# 9377      5    4                 1.3                1.65
# 9378      5    4                 2.0                2.30
# 9379      5    5                 1.5                1.70
#
#       HomeAvgGoalsConceded  AwayAvgGoalsConceded
# 9375                  1.65                  1.35
# 9376                  1.35                  1.55
# 9377                  1.80                  1.65
# 9378                  0.90                  1.30
# 9379                  1.15                  1.60
#
# [5 rows x 29 columns]

# %%
df["HomeWin"] = (df["FullTimeResult"] == "H").astype(int)
df["AwayWin"] = (df["FullTimeResult"] == "A").astype(int)

# %%
df.head()
# Out:
#     Season  MatchDate  HomeTeam       AwayTeam  FullTimeHomeGoals  \
# 0  2000/01 2000-08-19  Charlton       Man City                  4
# 1  2000/01 2000-08-19   Chelsea       West Ham                  4
# 2  2000/01 2000-08-19  Coventry  Middlesbrough                  1
# 3  2000/01 2000-08-19     Derby    Southampton                  2
# 4  2000/01 2000-08-19     Leeds        Everton                  2
#
#    FullTimeAwayGoals FullTimeResult  HalfTimeHomeGoals  HalfTimeAwayGoals  \
# 0                  0              H                  2                  0
# 1                  2              H                  1                  0
# 2                  3              A                  1                  1
# 3                  2              D                  1                  2
# 4                  0              H                  2                  0
#
#   HalfTimeResult  ...  AwayRedCards  Year  Month  Day  HomeAvgGoalsScored  \
# 0              H  ...             0  2000      8   19                 NaN
# 1              H  ...             0  2000      8   19                 NaN
# 2              D  ...             0  2000      8   19                 NaN
# 3              A  ...             0  2000      8   19                 NaN
# 4              H  ...             0  2000      8   19                 NaN
#
#    AwayAvgGoalsScored  HomeAvgGoalsConceded  AwayAvgGoalsConceded  HomeWin  \
# 0                 NaN                   NaN                   NaN        1
# 1                 NaN                   NaN                   NaN        1
# 2                 NaN                   NaN                   NaN        0
# 3                 NaN                   NaN                   NaN        0
# 4                 NaN                   NaN                   NaN        1
#
#    AwayWin
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#
# [5 rows x 31 columns]

# %%
df["HomeWinRate"] = rolling_team_feature(df, "HomeTeam", "HomeWin")
df["AwayWinRate"] = rolling_team_feature(df, "AwayTeam", "AwayWin")

# %%
df["HomeShotConversion"] = df["FullTimeHomeGoals"] / df["HomeShots"].replace(0, 1)
df["AwayShotConversion"] = df["FullTimeAwayGoals"] / df["AwayShots"].replace(0, 1)

df["HomeDisciplinary"] = df["HomeYellowCards"] + 3 * df["HomeRedCards"]
df["AwayDisciplinary"] = df["AwayYellowCards"] + 3 * df["AwayRedCards"]

# %%
df["MatchDayNumber"] = df.groupby("Season").cumcount() + 1

df["SeasonProgress"] = df["MatchDayNumber"] / df.groupby("Season")[
    "MatchDayNumber"
].transform("max")

# %%
df.head()
# Out:
#     Season  MatchDate  HomeTeam       AwayTeam  FullTimeHomeGoals  \
# 0  2000/01 2000-08-19  Charlton       Man City                  4
# 1  2000/01 2000-08-19   Chelsea       West Ham                  4
# 2  2000/01 2000-08-19  Coventry  Middlesbrough                  1
# 3  2000/01 2000-08-19     Derby    Southampton                  2
# 4  2000/01 2000-08-19     Leeds        Everton                  2
#
#    FullTimeAwayGoals FullTimeResult  HalfTimeHomeGoals  HalfTimeAwayGoals  \
# 0                  0              H                  2                  0
# 1                  2              H                  1                  0
# 2                  3              A                  1                  1
# 3                  2              D                  1                  2
# 4                  0              H                  2                  0
#
#   HalfTimeResult  ...  HomeWin  AwayWin  HomeWinRate  AwayWinRate  \
# 0              H  ...        1        0          NaN          NaN
# 1              H  ...        1        0          NaN          NaN
# 2              D  ...        0        1          NaN          NaN
# 3              A  ...        0        0          NaN          NaN
# 4              H  ...        1        0          NaN          NaN
#
#    HomeShotConversion  AwayShotConversion  HomeDisciplinary  AwayDisciplinary  \
# 0            0.235294            0.000000                 1                 2
# 1            0.235294            0.166667                 1                 2
# 2            0.166667            0.187500                 8                 3
# 3            0.333333            0.153846                 1                 1
# 4            0.117647            0.000000                 1                 3
#
#    MatchDayNumber  SeasonProgress
# 0               1        0.002632
# 1               2        0.005263
# 2               3        0.007895
# 3               4        0.010526
# 4               5        0.013158
#
# [5 rows x 39 columns]

# %%
home_freq = df["HomeTeam"].value_counts(normalize=True)
away_freq = df["AwayTeam"].value_counts(normalize=True)

df["HomeTeamFreqEnc"] = df["HomeTeam"].map(home_freq)
df["AwayTeamFreqEnc"] = df["AwayTeam"].map(away_freq)

# %%
df.head()
# Out:
#     Season  MatchDate  HomeTeam       AwayTeam  FullTimeHomeGoals  \
# 0  2000/01 2000-08-19  Charlton       Man City                  4
# 1  2000/01 2000-08-19   Chelsea       West Ham                  4
# 2  2000/01 2000-08-19  Coventry  Middlesbrough                  1
# 3  2000/01 2000-08-19     Derby    Southampton                  2
# 4  2000/01 2000-08-19     Leeds        Everton                  2
#
#    FullTimeAwayGoals FullTimeResult  HalfTimeHomeGoals  HalfTimeAwayGoals  \
# 0                  0              H                  2                  0
# 1                  2              H                  1                  0
# 2                  3              A                  1                  1
# 3                  2              D                  1                  2
# 4                  0              H                  2                  0
#
#   HalfTimeResult  ...  HomeWinRate  AwayWinRate  HomeShotConversion  \
# 0              H  ...          NaN          NaN            0.235294
# 1              H  ...          NaN          NaN            0.235294
# 2              D  ...          NaN          NaN            0.166667
# 3              A  ...          NaN          NaN            0.333333
# 4              H  ...          NaN          NaN            0.117647
#
#    AwayShotConversion  HomeDisciplinary  AwayDisciplinary  MatchDayNumber  \
# 0            0.000000                 1                 2               1
# 1            0.166667                 1                 2               2
# 2            0.187500                 8                 3               3
# 3            0.153846                 1                 1               4
# 4            0.000000                 1                 3               5
#
#    SeasonProgress  HomeTeamFreqEnc  AwayTeamFreqEnc
# 0        0.002632         0.013646         0.047974
# 1        0.005263         0.050000         0.044350
# 2        0.007895         0.002026         0.019723
# 3        0.010526         0.006077         0.033689
# 4        0.013158         0.013966         0.049787
#
# [5 rows x 41 columns]

# %%
df["GoalDifference"] = df["HomeAvgGoalsScored"] - df["AwayAvgGoalsScored"]
df["ExpectedGoalDiff"] = (df["HomeAvgGoalsScored"] - df["AwayAvgGoalsConceded"]) + (
    df["AwayAvgGoalsScored"] - df["HomeAvgGoalsConceded"]
)

# %%
df["FormDelta"] = df["HomeWinRate"] - df["AwayWinRate"]
df["HomeAvgShots"] = rolling_team_feature(df, "HomeTeam", "HomeShots")
df["AwayAvgShots"] = rolling_team_feature(df, "AwayTeam", "AwayShots")

# %%
df['ShotDifference'] = abs(df['HomeShots'] - df['AwayShots'])

df = df.sort_values(by='MatchDate')

# %%
df['HomeAvgGoalsConceded'] = 0.0
df['AwayAvgGoalsConceded'] = 0.0

home_conceded = df.groupby('HomeTeam')['FullTimeAwayGoals'].apply(lambda x: x.shift().expanding().mean())
away_conceded = df.groupby('AwayTeam')['FullTimeHomeGoals'].apply(lambda x: x.shift().expanding().mean())

df['HomeAvgGoalsConceded'] = home_conceded.values
df['AwayAvgGoalsConceded'] = away_conceded.values

df['DefensiveStrengthDifference'] = abs(df['HomeAvgGoalsConceded'] - df['AwayAvgGoalsConceded'])

# %%
df.dropna(
    subset=[
        "HomeAvgGoalsScored",
        "AwayAvgGoalsScored",
        "HomeAvgGoalsConceded",
        "AwayAvgGoalsConceded",
        "HomeWinRate",
        "AwayWinRate",
        "HomeShotConversion",
        "AwayShotConversion",
        "HomeDisciplinary",
        "AwayDisciplinary",
        "FullTimeResult",
        "ShotDifference",
        "DefensiveStrengthDifference"

    ],inplace=True
)

# %%
df.head()
# Out:
#      Season  MatchDate     HomeTeam    AwayTeam  FullTimeHomeGoals  \
# 26  2000/01 2000-08-26  Southampton   Liverpool                  3
# 19  2000/01 2000-08-26      Arsenal    Charlton                  5
# 20  2000/01 2000-08-26     Bradford   Leicester                  0
# 21  2000/01 2000-08-26      Everton       Derby                  2
# 22  2000/01 2000-08-26      Ipswich  Sunderland                  1
#
#     FullTimeAwayGoals FullTimeResult  HalfTimeHomeGoals  HalfTimeAwayGoals  \
# 26                  3              D                  0                  1
# 19                  3              H                  1                  2
# 20                  0              D                  0                  0
# 21                  2              D                  2                  0
# 22                  0              H                  0                  0
#
#    HalfTimeResult  ...  SeasonProgress  HomeTeamFreqEnc  AwayTeamFreqEnc  \
# 26              A  ...        0.071053         0.033902         0.050213
# 19              A  ...        0.052632         0.049893         0.013859
# 20              D  ...        0.055263         0.002026         0.025693
# 21              H  ...        0.057895         0.050213         0.006077
# 22              D  ...        0.060526         0.005864         0.028358
#
#     GoalDifference  ExpectedGoalDiff  FormDelta  HomeAvgShots  AwayAvgShots  \
# 26             1.0              -3.0        0.0          12.0           7.0
# 19             2.0              -1.0        1.0          17.0           8.0
# 20             1.0               3.0        0.0          12.0           4.0
# 21             1.0               2.0        1.0          13.0          10.0
# 22            -1.0              -2.0        0.0          13.0           9.0
#
#     ShotDifference  DefensiveStrengthDifference
# 26               5                     0.631579
# 19              11                     0.500000
# 20               5                     0.523810
# 21               5                     0.500000
# 22               5                     0.347826
#
# [5 rows x 48 columns]

# %%
features = [
    "HomeAvgGoalsScored",
    "AwayAvgGoalsScored",
    "HomeAvgGoalsConceded",
    "AwayAvgGoalsConceded",
    "HomeWinRate",
    "AwayWinRate",
    "HomeShotConversion",
    "AwayShotConversion",
    "HomeDisciplinary",
    "AwayDisciplinary",
    "SeasonProgress",
    "HomeTeamFreqEnc",
    "AwayTeamFreqEnc",
    "HomeAvgShots",
    "AwayAvgShots",
    "HomeShotsOnTarget",
    "AwayShotsOnTarget",
    "HomeCorners",
    "AwayCorners",
    "HomeFouls",
    "AwayFouls",
    "GoalDifference",
    "ExpectedGoalDiff",
    "FormDelta",
    "ShotDifference",
    "DefensiveStrengthDifference"
]
target = "FullTimeResult"

# %%
from sklearn.model_selection import train_test_split
X = df[features]
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42,stratify=y)

# %%
X_train.shape
# Out:
# (6457, 26)

# %%
y_train.shape
# Out:
# (6457,)

# %%
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(min_samples_split=10,min_samples_leaf=4,max_depth=10,random_state=42)  
model.fit(X_train, y_train)

print(
    "DecisionTreeClassifierModel Train Score is : ",
    model.score(X_train, y_train),
)
print(
    "DecisionTreeClassifierModel Test Score is : ",
    model.score(X_test, y_test),
)
print("----------------------------------------------------")

y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# DecisionTreeClassifierModel Train Score is :  0.9495121573486139
# DecisionTreeClassifierModel Test Score is :  0.914378612716763
# ----------------------------------------------------
#               precision    recall  f1-score   support
#
#            A       0.93      0.92      0.92       819
#            D       0.84      0.86      0.85       683
#            H       0.94      0.94      0.94      1266
#
#     accuracy                           0.91      2768
#    macro avg       0.91      0.91      0.91      2768
# weighted avg       0.91      0.91      0.91      2768

# %%
from sklearn.model_selection import learning_curve
train_sizes, train_scores, test_scores = learning_curve(
    model, X, y, cv=5, scoring='accuracy',
    train_sizes=np.linspace(0.1, 1.0, 10)
)

train_mean = train_scores.mean(axis=1)
test_mean = test_scores.mean(axis=1)

plt.plot(train_sizes, train_mean, label="Train Score")
plt.plot(train_sizes, test_mean, label="Validation Score")

plt.xlabel("Training Size")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Learning Curve")
plt.show()

# %%
def predict_match(df, model, home_team, away_team, feature_list):
    
    input_df = get_team_features(df, home_team, away_team)
    
    # Fill missing columns with mean values
    for col in feature_list:
        if col not in input_df:
            input_df[col] = df[col].mean()
    
    # Ensure correct column order
    input_df = input_df[feature_list]
    
    # Fill any NaN values
    input_df = input_df.fillna(df.mean(numeric_only=True))
    
    # Predict
    pred = model.predict(input_df)[0]
    proba = model.predict_proba(input_df)[0]
    
    # Get correct class order
    classes = model.classes_
    prob_dict = dict(zip(classes, proba))
    
    return {
        "HomeTeam": home_team,
        "AwayTeam": away_team,
        "Prediction": pred,
        "AwayWinProb": prob_dict.get("A", 0),
        "DrawProb": prob_dict.get("D", 0),
        "HomeWinProb": prob_dict.get("H", 0)
    }

# %%
feature_list = X.columns.tolist()
result = predict_match(df, model, "Arsenal", "Chelsea",feature_list)
print(result)
# Out:
# {'HomeTeam': 'Arsenal', 'AwayTeam': 'Chelsea', 'Prediction': 'D', 'AwayWinProb': np.float64(0.3333333333333333), 'DrawProb': np.float64(0.6666666666666666), 'HomeWinProb': np.float64(0.0)}
